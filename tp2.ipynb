# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_openai.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.agents import create_agent
from langchain_openai import OpenAI
from dotenv import load_dotenv
from langchain.tools import tool
from langchain_text_splitters import RecursiveCharacterTextSplitter
import tiktoken

# %%
load_dotenv()
# Out:
# True

# %%
loader = PyPDFLoader("bipresentation.pdf")

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4o-mini")

# %%
splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name=tokenizer.name,
    chunk_size=1000,
    chunk_overlap=200
)

# %%
chunks= loader.load_and_split(splitter)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\DELL\Documents\agents\agentic_langgraph\.venv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:359, in PyPDFParser.lazy_parse(self, blob)
#     358 try:
# --> 359     import pypdf
#     360 except ImportError:
#
# ModuleNotFoundError: No module named 'pypdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 chunks= loader.load_and_split(splitter)
#
# File c:\Users\DELL\Documents\agents\agentic_langgraph\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:86, in BaseLoader.load_and_split(self, text_splitter)
#      84 else:
#      85     text_splitter_ = text_splitter
# ---> 86 docs = self.load()
#      87 return text_splitter_.split_documents(docs)
#
# File c:\Users\DELL\Documents\agents\agentic_langgraph\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Users\DELL\Documents\agents\agentic_langgraph\.venv\Lib\site-packages\langchain_community\document_loaders\pdf.py:305, in PyPDFLoader.lazy_load(self)
#     303 else:
#     304     blob = Blob.from_path(self.file_path)
# --> 305 yield from self.parser.lazy_parse(blob)
#
# File c:\Users\DELL\Documents\agents\agentic_langgraph\.venv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:361, in PyPDFParser.lazy_parse(self, blob)
#     359     import pypdf
#     360 except ImportError:
# --> 361     raise ImportError(
#     362         "`pypdf` package not found, please install it with `pip install pypdf`"
#     363     )
#     365 def _extract_text_from_page(page: pypdf.PageObject) -> str:
#     366     """
#     367     Extract text from image given the version of pypdf.
#     368
#    (...)    373         str: The extracted text.
#     374     """
#
# ImportError: `pypdf` package not found, please install it with `pip install pypdf`
